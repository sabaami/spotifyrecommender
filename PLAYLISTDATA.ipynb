# %%
import pandas as ps
import json 
import csv
import requests

import matplotlib.pyplot as plt

import spotipy 
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials





#/Users/sabaamiri/Downloads/Playlist1.json

# %%
df = ps.read_csv(r'/Users/sabaamiri/Downloads/Playlist1(1).csv')

# %%
df= df.apply(lambda x: x.dropna().reset_index(drop = True))

# %%
df []
# Out:
#              playlists/name playlists/lastModifiedDate  \
# 0                the heart                  2022-05-02
# 1                toxicity 💫                 2022-04-30
# 2           WHEN SPARKS FLY                 2022-05-01
# 3                 classics🌻                 2022-04-21
# 4   spring/summer '22 ✨🍑🥥🌸🌺                 2022-05-02
# ..                      ...                        ...
# 78                   HipHop                 2018-09-14
# 79        Mit Star bewertet                 2018-09-14
# 80                   Random                 2018-09-14
# 81             splash! 21 🌊                 2020-10-08
# 82            Neue Playlist                 2018-09-14
#
#                     playlists/items/0/track/trackName  \
# 0                                         Temptations
# 1                                     Let Me Love You
# 2                                     WHEN SPARKS FLY
# 3                                                Free
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='localTrack')))]

# %%
df
# Out:
#              playlists/name playlists/lastModifiedDate  \
# 0                the heart                  2022-05-02
# 1                toxicity 💫                 2022-04-30
# 2           WHEN SPARKS FLY                 2022-05-01
# 3                 classics🌻                 2022-04-21
# 4   spring/summer '22 ✨🍑🥥🌸🌺                 2022-05-02
# ..                      ...                        ...
# 78                   HipHop                 2018-09-14
# 79        Mit Star bewertet                 2018-09-14
# 80                   Random                 2018-09-14
# 81             splash! 21 🌊                 2020-10-08
# 82            Neue Playlist                 2018-09-14
#
#                     playlists/items/0/track/trackName  \
# 0                                         Temptations
# 1                                     Let Me Love You
# 2                                     WHEN SPARKS FLY
# 3                                                Free
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='episode')))]

# %%
df.tail(5)
# Out:
#        playlists/name playlists/lastModifiedDate  \
# 78             HipHop                 2018-09-14
# 79  Mit Star bewertet                 2018-09-14
# 80             Random                 2018-09-14
# 81       splash! 21 🌊                 2020-10-08
# 82      Neue Playlist                 2018-09-14
#
#                playlists/items/0/track/trackName  \
# 78                               I Luv This Shit
# 79                When The Love Falls - Original
# 80  Where This Flower Blooms (feat. Frank Ocean)
# 81                            You Belong With Me
# 82                                           NaN
#
#    playlists/items/0/track/artistName     playlists/items/0/track/albumName  \
# 78                      August Alsina          Downtown: Life Under The Gun
# 79                             Yiruma  First Love (Yiruma Piano Collection)
# 80                 Tyler, The Creator                            Flower Boy
# ...

# %%
df= df.apply(lambda x: x.dropna().reset_index(drop = True))

# %%
df
# Out:
#              playlists/name playlists/lastModifiedDate  \
# 0                the heart                  2022-05-02
# 1                toxicity 💫                 2022-04-30
# 2           WHEN SPARKS FLY                 2022-05-01
# 3                 classics🌻                 2022-04-21
# 4   spring/summer '22 ✨🍑🥥🌸🌺                 2022-05-02
# ..                      ...                        ...
# 78                   HipHop                 2018-09-14
# 79        Mit Star bewertet                 2018-09-14
# 80                   Random                 2018-09-14
# 81             splash! 21 🌊                 2020-10-08
# 82            Neue Playlist                 2018-09-14
#
#                     playlists/items/0/track/trackName  \
# 0                                         Temptations
# 1                                     Let Me Love You
# 2                                     WHEN SPARKS FLY
# 3                                                Free
# ...
